# %%
#!/usr/bin/env python
# coding: utf-8

# # WeatherPy
# ----
# 
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# In[1]:


# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from urllib.error import HTTPError
import openweathermapy.core as owm

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)


# ## Generate Cities List

# In[ ]:


# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# %%
# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 596

# %%
 ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

settings = {"units": "imperial","appid": api_key}

weather_data =[]

city_number=1

for city in cities:
    try:
        weather_data.append(owm.get_current(city, **settings))
        print(f"Processiong Record {city_number} | {city}")
        city_number+=1
    except:
        print("City not found. Skipping...")

        
    time.sleep(1)
    
print("---------------------")
print("fin")
# Out:
# Processiong Record 1 | jamestown
# Processiong Record 2 | qaanaaq
# Processiong Record 3 | yellowknife
# Processiong Record 4 | tura
# Processiong Record 5 | mackenzie
# Processiong Record 6 | mataura
# Processiong Record 7 | cape town
# Processiong Record 8 | tiksi
# Processiong Record 9 | hualmay
# City not found. Skipping...
# Processiong Record 10 | busselton
# Processiong Record 11 | punta arenas
# Processiong Record 12 | yerazgavors
# Processiong Record 13 | saint-philippe
# Processiong Record 14 | ventspils
# Processiong Record 15 | seydi
# Processiong Record 16 | vaini
# Processiong Record 17 | kodiak
# Processiong Record 18 | albany
# City not found. Skipping...
# Processiong Record 19 | zonhoven
# Processiong Record 20 | atuona
# Processiong Record 21 | gat
# Processiong Record 22 | itamarandiba
# Processiong Record 23 | fortuna
# City not found. Skipping...
# Processiong Record 24 | port talbot
# Processiong Record 25 | ushuaia
# Processiong Record 26 | avarua
# Processiong Record 27 | wainwright
# Processiong Record 28 | fayaoue
# Processiong Record 29 | aviles
# Processiong Record 30 | kruisfontein
# Processiong Record 31 | sambava
# Processiong Record 32 | point pedro
# Processiong Record 33 | lavrentiya
# Processiong Record 34 | new norfolk
# City not found. Skipping...
# Processiong Record 35 | nizhnyaya tavda
# Processiong Record 36 | takaka
# Processiong Record 37 | dikson
# Processiong Record 38 | camocim
# Processiong Record 39 | husavik
# Processiong Record 40 | nurota
# Processiong Record 41 | mount isa
# Processiong Record 42 | castro
# Processiong Record 43 | omboue
# Processiong Record 44 | samana
# Processiong Record 45 | ponta do sol
# Processiong Record 46 | richards bay
# Processiong Record 47 | chirongui
# Processiong Record 48 | rikitea
# Processiong Record 49 | lagoa
# Processiong Record 50 | longyearbyen
# City not found. Skipping...
# Processiong Record 51 | hay river
# Processiong Record 52 | gari
# Processiong Record 53 | bluff
# Processiong Record 54 | mayo
# Processiong Record 55 | guangyuan
# Processiong Record 56 | vao
# Processiong Record 57 | amalapuram
# Processiong Record 58 | turka
# Processiong Record 59 | dodoma
# Processiong Record 60 | san cristobal
# Processiong Record 61 | san patricio
# Processiong Record 62 | bredasdorp
# Processiong Record 63 | ulaangom
# Processiong Record 64 | cecina
# Processiong Record 65 | lyubech
# Processiong Record 66 | nikolskoye
# Processiong Record 67 | panalingaan
# City not found. Skipping...
# Processiong Record 68 | taraz
# Processiong Record 69 | puerto del rosario
# Processiong Record 70 | lorengau
# Processiong Record 71 | severo-kurilsk
# City not found. Skipping...
# Processiong Record 72 | jurado
# Processiong Record 73 | deputatskiy
# City not found. Skipping...
# Processiong Record 74 | hermanus
# Processiong Record 75 | rio gallegos
# Processiong Record 76 | grand gaube
# Processiong Record 77 | hobart
# City not found. Skipping...
# Processiong Record 78 | san antonio
# Processiong Record 79 | saskylakh
# Processiong Record 80 | port lincoln
# Processiong Record 81 | quatre cocos
# Processiong Record 82 | pacific grove
# Processiong Record 83 | funtua
# Processiong Record 84 | hofn
# City not found. Skipping...
# Processiong Record 85 | kaitangata
# Processiong Record 86 | chatrapur
# Processiong Record 87 | kahului
# Processiong Record 88 | puerto ayora
# Processiong Record 89 | carnarvon
# Processiong Record 90 | kapaa
# Processiong Record 91 | padampur
# Processiong Record 92 | alofi
# Processiong Record 93 | sao jose da coroa grande
# Processiong Record 94 | marawi
# Processiong Record 95 | victoria
# Processiong Record 96 | kongoussi
# Processiong Record 97 | caraguatatuba
# City not found. Skipping...
# Processiong Record 98 | sechura
# Processiong Record 99 | port elizabeth
# Processiong Record 100 | gweta
# Processiong Record 101 | ribeira grande
# Processiong Record 102 | cherskiy
# Processiong Record 103 | khatanga
# Processiong Record 104 | saint george
# Processiong Record 105 | hilo
# Processiong Record 106 | loon
# Processiong Record 107 | beira
# Processiong Record 108 | upernavik
# Processiong Record 109 | kudahuvadhoo
# Processiong Record 110 | port augusta
# Processiong Record 111 | yar-sale
# Processiong Record 112 | vardo
# Processiong Record 113 | jatara
# Processiong Record 114 | hamilton
# Processiong Record 115 | lata
# City not found. Skipping...
# City not found. Skipping...
# Processiong Record 116 | dzhebariki-khaya
# Processiong Record 117 | amapa
# Processiong Record 118 | brandon
# Processiong Record 119 | mahebourg
# Processiong Record 120 | faya
# Processiong Record 121 | eureka
# Processiong Record 122 | khadki
# Processiong Record 123 | narsaq
# Processiong Record 124 | souillac
# Processiong Record 125 | pachino
# Processiong Record 126 | shimanovsk
# Processiong Record 127 | lebu
# Processiong Record 128 | chokurdakh
# Processiong Record 129 | huarmey
# City not found. Skipping...
# Processiong Record 130 | nizwa
# Processiong Record 131 | latung
# Processiong Record 132 | coxim
# Processiong Record 133 | miri
# Processiong Record 134 | jinchang
# Processiong Record 135 | rio tercero
# Processiong Record 136 | komsomolskiy
# Processiong Record 137 | tuatapere
# Processiong Record 138 | barra do garcas
# Processiong Record 139 | flinders
# Processiong Record 140 | takoradi
# Processiong Record 141 | mitu
# Processiong Record 142 | ilulissat
# Processiong Record 143 | mehamn
# Processiong Record 144 | vanimo
# Processiong Record 145 | isangel
# Processiong Record 146 | vila velha
# Processiong Record 147 | udachnyy
# Processiong Record 148 | balkanabat
# Processiong Record 149 | barrow
# Processiong Record 150 | lompoc
# Processiong Record 151 | jiuquan
# Processiong Record 152 | dalby
# Processiong Record 153 | phibun mangsahan
# Processiong Record 154 | prince rupert
# Processiong Record 155 | hami
# Processiong Record 156 | vila franca do campo
# Processiong Record 157 | shubarkuduk
# Processiong Record 158 | tuktoyaktuk
# City not found. Skipping...
# Processiong Record 159 | alto araguaia
# City not found. Skipping...
# Processiong Record 160 | bograd
# Processiong Record 161 | moron
# Processiong Record 162 | butaritari
# Processiong Record 163 | caravelas
# Processiong Record 164 | harrisonville
# Processiong Record 165 | bilma
# Processiong Record 166 | odweyne
# City not found. Skipping...
# Processiong Record 167 | katsuura
# Processiong Record 168 | anderson
# Processiong Record 169 | touros
# Processiong Record 170 | chilca
# Processiong Record 171 | aguimes
# Processiong Record 172 | camana
# Processiong Record 173 | maumere
# Processiong Record 174 | zhigansk
# Processiong Record 175 | port alfred
# Processiong Record 176 | voznesenye
# Processiong Record 177 | tautira
# Processiong Record 178 | mar del plata
# City not found. Skipping...
# Processiong Record 179 | provideniya
# Processiong Record 180 | luderitz
# Processiong Record 181 | paamiut
# Processiong Record 182 | ancud
# Processiong Record 183 | arraial do cabo
# Processiong Record 184 | pangnirtung
# Processiong Record 185 | kuytun
# Processiong Record 186 | boulder
# Processiong Record 187 | vestmannaeyjar
# Processiong Record 188 | skjervoy
# Processiong Record 189 | bambous virieux
# Processiong Record 190 | prudentopolis
# Processiong Record 191 | limbang
# Processiong Record 192 | palmas
# Processiong Record 193 | torbay
# Processiong Record 194 | nhulunbuy
# Processiong Record 195 | sobolevo
# Processiong Record 196 | sorong
# Processiong Record 197 | airai
# Processiong Record 198 | kibaya
# City not found. Skipping...
# Processiong Record 199 | west wendover
# Processiong Record 200 | hermsdorf
# Processiong Record 201 | cidreira
# Processiong Record 202 | samarinda
# Processiong Record 203 | evensk
# Processiong Record 204 | srednekolymsk
# Processiong Record 205 | east london
# Processiong Record 206 | fomboni
# Processiong Record 207 | riyadh
# Processiong Record 208 | baherden
# Processiong Record 209 | jeremie
# Processiong Record 210 | gheorghe lazar
# City not found. Skipping...
# Processiong Record 211 | goderich
# Processiong Record 212 | longhua
# Processiong Record 213 | nizhniy tsasuchey
# Processiong Record 214 | codrington
# Processiong Record 215 | esterhazy
# Processiong Record 216 | bathsheba
# Processiong Record 217 | faanui
# Processiong Record 218 | anna
# Processiong Record 219 | meulaboh
# Processiong Record 220 | caidian
# Processiong Record 221 | itarema
# Processiong Record 222 | abnub
# Processiong Record 223 | cumana
# Processiong Record 224 | georgetown
# Processiong Record 225 | tasiilaq
# Processiong Record 226 | najran
# Processiong Record 227 | los llanos de aridane
# Processiong Record 228 | kankan
# Processiong Record 229 | porto novo
# Processiong Record 230 | plettenberg bay
# City not found. Skipping...
# Processiong Record 231 | nantucket
# Processiong Record 232 | zhuhai
# Processiong Record 233 | leningradskiy
# Processiong Record 234 | manado
# Processiong Record 235 | zhangjiakou
# Processiong Record 236 | virginia beach
# Processiong Record 237 | college
# Processiong Record 238 | tigzirt
# Processiong Record 239 | langsa
# Processiong Record 240 | tolu
# Processiong Record 241 | seoul
# Processiong Record 242 | los chiles
# Processiong Record 243 | laurel
# Processiong Record 244 | mount gambier
# Processiong Record 245 | zaozerne
# Processiong Record 246 | kavieng
# Processiong Record 247 | chuy
# Processiong Record 248 | markala
# Processiong Record 249 | manokwari
# Processiong Record 250 | qasigiannguit
# Processiong Record 251 | mamallapuram
# Processiong Record 252 | iralaya
# Processiong Record 253 | kuryk
# City not found. Skipping...
# Processiong Record 254 | huntington
# Processiong Record 255 | chiredzi
# Processiong Record 256 | lasa
# Processiong Record 257 | staroaleyskoye
# Processiong Record 258 | swansea
# Processiong Record 259 | chaoyang
# City not found. Skipping...
# Processiong Record 260 | pevek
# City not found. Skipping...
# Processiong Record 261 | ewa beach
# Processiong Record 262 | swan river
# Processiong Record 263 | nadym
# Processiong Record 264 | kindu
# Processiong Record 265 | tripoli
# Processiong Record 266 | babu
# City not found. Skipping...
# Processiong Record 267 | mezhova
# Processiong Record 268 | gambela
# Processiong Record 269 | russell
# Processiong Record 270 | banda aceh
# Processiong Record 271 | gladstone
# Processiong Record 272 | roma
# Processiong Record 273 | bengkulu
# Processiong Record 274 | maldonado
# Processiong Record 275 | bethel
# Processiong Record 276 | tocopilla
# Processiong Record 277 | coquimbo
# City not found. Skipping...
# Processiong Record 278 | beringovskiy
# Processiong Record 279 | erzin
# City not found. Skipping...
# Processiong Record 280 | ardmore
# Processiong Record 281 | hammerfest
# Processiong Record 282 | ripon
# Processiong Record 283 | fort nelson
# Processiong Record 284 | marystown
# Processiong Record 285 | klaksvik
# Processiong Record 286 | whitehorse
# City not found. Skipping...
# Processiong Record 287 | lipari
# Processiong Record 288 | kaiyuan
# Processiong Record 289 | ise
# Processiong Record 290 | kuching
# Processiong Record 291 | cabo san lucas
# Processiong Record 292 | san pedro
# Processiong Record 293 | uklana mandi
# Processiong Record 294 | san lorenzo
# Processiong Record 295 | pisco
# Processiong Record 296 | kavaratti
# Processiong Record 297 | fairbanks
# Processiong Record 298 | lac du bonnet
# Processiong Record 299 | xichang
# Processiong Record 300 | dali
# Processiong Record 301 | puerto carreno
# City not found. Skipping...
# Processiong Record 302 | bafq
# Processiong Record 303 | bideford
# Processiong Record 304 | cabanas
# Processiong Record 305 | esna
# Processiong Record 306 | tashara
# Processiong Record 307 | nouadhibou
# Processiong Record 308 | high level
# Processiong Record 309 | dudinka
# Processiong Record 310 | birin
# Processiong Record 311 | havelock
# Processiong Record 312 | la palma
# Processiong Record 313 | natal
# Processiong Record 314 | yulara
# City not found. Skipping...
# Processiong Record 315 | elesbao veloso
# Processiong Record 316 | hasaki
# Processiong Record 317 | otradnoye
# Processiong Record 318 | kutiyana
# Processiong Record 319 | tenenkou
# Processiong Record 320 | gadsden
# Processiong Record 321 | paso de los toros
# Processiong Record 322 | pochutla
# Processiong Record 323 | khandyga
# Processiong Record 324 | naze
# Processiong Record 325 | cayenne
# Processiong Record 326 | dingle
# Processiong Record 327 | alta floresta
# City not found. Skipping...
# Processiong Record 328 | arman
# Processiong Record 329 | grants pass
# Processiong Record 330 | ranong
# Processiong Record 331 | coihaique
# Processiong Record 332 | alyangula
# Processiong Record 333 | aklavik
# Processiong Record 334 | guerrero negro
# Processiong Record 335 | mahon
# Processiong Record 336 | dunedin
# Processiong Record 337 | kenai
# Processiong Record 338 | hoi an
# Processiong Record 339 | pangai
# City not found. Skipping...
# Processiong Record 340 | iqaluit
# Processiong Record 341 | istok
# Processiong Record 342 | ciudad bolivar
# Processiong Record 343 | shellbrook
# Processiong Record 344 | esperance
# Processiong Record 345 | opuwo
# Processiong Record 346 | orange cove
# Processiong Record 347 | hithadhoo
# Processiong Record 348 | rondonopolis
# Processiong Record 349 | nanortalik
# Processiong Record 350 | sao filipe
# Processiong Record 351 | xining
# Processiong Record 352 | samarai
# Processiong Record 353 | xuanwu
# Processiong Record 354 | chyhyryn
# Processiong Record 355 | nuevo progreso
# Processiong Record 356 | san jeronimo
# Processiong Record 357 | norman wells
# Processiong Record 358 | itoman
# Processiong Record 359 | durban
# Processiong Record 360 | lewiston
# Processiong Record 361 | thompson
# Processiong Record 362 | dwarka
# Processiong Record 363 | voh
# Processiong Record 364 | port hardy
# Processiong Record 365 | manali
# Processiong Record 366 | sur
# Processiong Record 367 | brookhaven
# Processiong Record 368 | nha trang
# Processiong Record 369 | ahuimanu
# City not found. Skipping...
# Processiong Record 370 | nunoa
# Processiong Record 371 | svetlogorsk
# Processiong Record 372 | weston
# Processiong Record 373 | thinadhoo
# Processiong Record 374 | guiratinga
# Processiong Record 375 | bubaque
# Processiong Record 376 | ayan
# City not found. Skipping...
# Processiong Record 377 | korla
# Processiong Record 378 | cacador
# Processiong Record 379 | diu
# Processiong Record 380 | sakakah
# Processiong Record 381 | polyanka
# Processiong Record 382 | bonavista
# Processiong Record 383 | port blair
# Processiong Record 384 | westport
# Processiong Record 385 | floro
# Processiong Record 386 | tam ky
# Processiong Record 387 | vondrozo
# City not found. Skipping...
# City not found. Skipping...
# Processiong Record 388 | fare
# Processiong Record 389 | boyolangu
# Processiong Record 390 | great yarmouth
# Processiong Record 391 | atar
# Processiong Record 392 | andra
# Processiong Record 393 | ketchikan
# City not found. Skipping...
# Processiong Record 394 | haines junction
# City not found. Skipping...
# Processiong Record 395 | rawson
# Processiong Record 396 | ostrovnoy
# Processiong Record 397 | asau
# Processiong Record 398 | gogrial
# Processiong Record 399 | sokoni
# Processiong Record 400 | doha
# Processiong Record 401 | kampene
# Processiong Record 402 | yumen
# Processiong Record 403 | nueve de julio
# Processiong Record 404 | straumen
# Processiong Record 405 | luancheng
# Processiong Record 406 | vila
# Processiong Record 407 | ozernovskiy
# City not found. Skipping...
# Processiong Record 408 | bandarbeyla
# Processiong Record 409 | port macquarie
# Processiong Record 410 | sovetskaya gavan
# Processiong Record 411 | zhezkazgan
# Processiong Record 412 | beroroha
# Processiong Record 413 | santa cruz
# Processiong Record 414 | camacha
# Processiong Record 415 | bandar
# Processiong Record 416 | angouleme
# Processiong Record 417 | florida
# Processiong Record 418 | valdemarpils
# Processiong Record 419 | bar harbor
# Processiong Record 420 | bud
# Processiong Record 421 | acajutla
# Processiong Record 422 | logan
# Processiong Record 423 | batangafo
# Processiong Record 424 | buin
# Processiong Record 425 | geraldton
# Processiong Record 426 | siemiatycze
# Processiong Record 427 | avera
# Processiong Record 428 | zhengjiatun
# City not found. Skipping...
# Processiong Record 429 | lethem
# Processiong Record 430 | clyde river
# Processiong Record 431 | pemangkat
# Processiong Record 432 | nicoya
# Processiong Record 433 | ustka
# Processiong Record 434 | hambantota
# Processiong Record 435 | namibe
# Processiong Record 436 | mankono
# Processiong Record 437 | borba
# Processiong Record 438 | coahuayana
# Processiong Record 439 | luba
# Processiong Record 440 | liverpool
# Processiong Record 441 | kapoeta
# Processiong Record 442 | carauari
# Processiong Record 443 | progreso
# Processiong Record 444 | kyra
# Processiong Record 445 | saint anthony
# Processiong Record 446 | porto walter
# Processiong Record 447 | la ronge
# Processiong Record 448 | leshukonskoye
# Processiong Record 449 | walvis bay
# Processiong Record 450 | lalmohan
# Processiong Record 451 | huilong
# Processiong Record 452 | tsabong
# Processiong Record 453 | kangaatsiaq
# Processiong Record 454 | huaraz
# Processiong Record 455 | saldanha
# Processiong Record 456 | padang
# Processiong Record 457 | ambilobe
# Processiong Record 458 | derzhavinsk
# Processiong Record 459 | olinda
# Processiong Record 460 | constitucion
# Processiong Record 461 | creel
# Processiong Record 462 | saint-pierre
# Processiong Record 463 | peniche
# Processiong Record 464 | laem sing
# Processiong Record 465 | taltal
# Processiong Record 466 | boden
# Processiong Record 467 | ilo
# Processiong Record 468 | anadyr
# Processiong Record 469 | kirkenaer
# Processiong Record 470 | baykit
# Processiong Record 471 | abu samrah
# City not found. Skipping...
# Processiong Record 472 | bantou
# Processiong Record 473 | khanpur
# Processiong Record 474 | rio grande
# Processiong Record 475 | muromtsevo
# Processiong Record 476 | vught
# Processiong Record 477 | wahpeton
# Processiong Record 478 | abalak
# Processiong Record 479 | aitape
# Processiong Record 480 | rameswaram
# Processiong Record 481 | yerbogachen
# Processiong Record 482 | nakhon phanom
# Processiong Record 483 | forbes
# Processiong Record 484 | turbat
# Processiong Record 485 | melito di porto salvo
# Processiong Record 486 | languyan
# Processiong Record 487 | zhenhai
# Processiong Record 488 | yanam
# Processiong Record 489 | broken hill
# Processiong Record 490 | bandundu
# Processiong Record 491 | cherepovets
# Processiong Record 492 | maniitsoq
# Processiong Record 493 | santona
# Processiong Record 494 | kitimat
# Processiong Record 495 | aquiraz
# City not found. Skipping...
# Processiong Record 496 | warmbad
# Processiong Record 497 | caribou
# Processiong Record 498 | cap malheureux
# Processiong Record 499 | mehran
# Processiong Record 500 | singaparna
# City not found. Skipping...
# Processiong Record 501 | milkovo
# Processiong Record 502 | yeppoon
# Processiong Record 503 | penarroya-pueblonuevo
# Processiong Record 504 | calvinia
# Processiong Record 505 | guanica
# City not found. Skipping...
# Processiong Record 506 | tekeli
# Processiong Record 507 | tornio
# Processiong Record 508 | aswan
# City not found. Skipping...
# City not found. Skipping...
# Processiong Record 509 | wanning
# Processiong Record 510 | sterling
# Processiong Record 511 | krasnogorskoye
# Processiong Record 512 | mitsamiouli
# Processiong Record 513 | berlevag
# Processiong Record 514 | koppa
# Processiong Record 515 | karratha
# Processiong Record 516 | pontivy
# Processiong Record 517 | kuusamo
# Processiong Record 518 | talnakh
# Processiong Record 519 | vredendal
# Processiong Record 520 | synya
# Processiong Record 521 | camacupa
# Processiong Record 522 | jeremoabo
# Processiong Record 523 | buraydah
# Processiong Record 524 | emba
# Processiong Record 525 | santa cruz do sul
# Processiong Record 526 | butembo
# Processiong Record 527 | hangu
# Processiong Record 528 | porbandar
# Processiong Record 529 | bosobolo
# Processiong Record 530 | labuhan
# Processiong Record 531 | bakel
# Processiong Record 532 | reserva
# Processiong Record 533 | mayumba
# Processiong Record 534 | kachiry
# Processiong Record 535 | risod
# Processiong Record 536 | jian
# Processiong Record 537 | san luis
# Processiong Record 538 | awjilah
# Processiong Record 539 | lucea
# Processiong Record 540 | almeirim
# Processiong Record 541 | abbeyfeale
# Processiong Record 542 | san quintin
# Processiong Record 543 | broome
# Processiong Record 544 | loa janan
# Processiong Record 545 | valentin gomez farias
# Processiong Record 546 | bartica
# Processiong Record 547 | joaima
# Processiong Record 548 | isiro
# Processiong Record 549 | quimper
# Processiong Record 550 | manta
# ---------------------
# fin

# %%
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame
summary = ["name","clouds.all","sys.country","dt","main.humidity","coord.lat", "coord.lon","main.temp_max","wind.speed"]

column_names = ["City","Cloudiness","Country","Date ","Humidity", "Lat","Lng", "Max Temp", "Wind Speed"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]

weather_data_df = pd.DataFrame(data,columns=column_names)

city_weather_df=weather_data_df.set_index("City")

city_weather_count=city_weather_df.count()

print(city_weather_count)
# Out:
# Cloudiness    550
# Country       550
# Date          550
# Humidity      550
# Lat           550
# Lng           550
# Max Temp      550
# Wind Speed    550
# dtype: int64

# %%
city_weather_df
# Out:
#                        Cloudiness Country       Date   Humidity    Lat  \
# City
# Jamestown                      90      US  1579059097        93  42.10
# Qaanaaq                        76      GL  1579059098        55  77.48
# Yellowknife                    75      CA  1579059084        73  62.46
# Tura                            0      IN  1579059100        56  25.52
# Mackenzie                      90      CA  1579059101        75  55.30
# Mataura                         0      NZ  1579059102        59 -46.19
# Cape Town                      75      ZA  1579059103        88 -33.93
# Tiksi                         100      RU  1579059104        88  71.69
# Hualmay                        95      PE  1579059105        84 -11.10
# Busselton                       0      AU  1579059107        27 -33.65
# Punta Arenas                   20      CL  1579058941        70 -53.15
# Yerazgavors                    40      AM  1579059109        78  40.70
# Saint-Philippe                  0      RE  1579059110        65 -21.36
# Ventspils                      90      LV  1579059077        87  57.39
# Seydi                          75      TM  1579059113        54  39.48
# Vaini                          40      TO  1579059114        74 -21.20
# Kodiak                         40      US  1579059115        53  57.79
# Albany                         90      US  1579059045        75  42.60
# Zonhoven                       43      BE  1579059118        71  50.99
# Atuona                          1      PF  1579059119        74  -9.80
# Kiryat Gat                     40      IL  1579059001        81  31.61
# Itamarandiba                   96      BR  1579059121        98 -17.86
# Fortuna                        75      US  1579059122        87  40.60
# Port Talbot                    40      GB  1579059124        81  51.59
# Ushuaia                        75      AR  1579058969        65 -54.80
# Avarua                         74      CK  1579059127        78 -21.21
# Wainwright                    100      CA  1579059128        93  52.84
# Fayaoue                        21      NC  1579059129        79 -20.65
# Aviles                         75      ES  1579059130        48  43.55
# Kruisfontein                    2      ZA  1579059131        95 -34.00
# ...                           ...     ...         ...       ...    ...
# Camacupa                       97      AO  1579059702        93 -12.02
# Jeremoabo                       0      BR  1579059703        92 -10.07
# Buraidah                        7      SA  1579059704        69  26.33
# Emba                           92      KZ  1579059705        97  48.83
# Santa Cruz do Sul               0      BR  1579059706        85 -29.72
# Butembo                         1      CD  1579059708        72   0.15
# Hangu                           0      CN  1579059709        49  39.25
# Porbandar                       0      IN  1579059710        62  21.64
# Bosobolo                        0      CD  1579059711        45   4.18
# Labuhan                        96      ID  1579059712        72  -6.88
# Bakel                         100      SN  1579059713        13  14.90
# Reserva                        16      BR  1579059714        98 -24.65
# Mayumba                        81      GA  1579059715        78  -3.43
# Qashyr                        100      KZ  1579059716        94  53.07
# Risod                           0      IN  1579059717        66  19.97
# Jian                          100      CN  1579059718        94  27.12
# San Luis                       78      AR  1579059719        51 -33.30
# Awjilah                       100      LY  1579059720        84  29.11
# Lucea                          40      JM  1579059722        69  18.45
# Almeirim                       62      BR  1579059723        87  -1.52
# Abbeyfeale                     75      IE  1579059724        80  52.38
# San Quintin                    69      MX  1579059460        83  30.48
# Broome                         90      US  1579059726        93  42.25
# Loa Janan                      64      ID  1579059727        53  -0.58
# Valentin Gomez Farias         100      MX  1579059728        25  28.22
# Bartica                        75      GY  1579059729       100   6.40
# Joaima                         15      BR  1579059730        95 -16.65
# Isiro                          13      CD  1579059731        47   2.77
# Quimper                       100      FR  1579059732        87  48.00
# Manta                          75      EC  1579059733        83  -0.95
#
#                           Lng  Max Temp  Wind Speed
# City
# Jamestown              -79.24     39.99       10.29
# Qaanaaq                -69.36    -14.94        7.40
# Yellowknife           -114.35    -32.80        2.24
# Tura                    90.22     68.94        1.03
# Mackenzie             -123.17    -14.80        5.21
# Mataura                168.86     66.90       10.56
# Cape Town               18.42     72.00       11.41
# Tiksi                  128.87     -8.48       10.18
# Hualmay                -77.61     67.17        1.95
# Busselton              115.33     82.00       14.23
# Punta Arenas           -70.92     42.80       13.87
# Yerazgavors             43.75     12.20        3.20
# Saint-Philippe          55.77     82.99        5.82
# Ventspils               21.56     44.60       20.80
# Seydi                   62.91     30.27        9.19
# Vaini                 -175.20     84.20       12.75
# Kodiak                -152.41     26.60       17.22
# Albany                 -73.97     41.00       12.75
# Zonhoven                 5.37     53.60       14.99
# Atuona                -139.03     81.43       18.48
# Kiryat Gat              34.76     55.00        2.24
# Itamarandiba           -42.86     65.68        3.31
# Fortuna               -124.16     43.00        4.70
# Port Talbot             -3.78     46.40       10.29
# Ushuaia                -68.30     44.60       27.51
# Avarua                -159.78     80.60       16.11
# Wainwright            -110.86    -29.81        6.06
# Fayaoue                166.53     80.17       18.25
# Aviles                  -5.92     62.01        3.36
# Kruisfontein            24.73     65.61        3.65
# ...                       ...       ...         ...
# Camacupa                17.48     60.64        4.21
# Jeremoabo              -38.48     65.98        6.44
# Buraidah                43.98     35.60        4.81
# Emba                    58.14     14.63        9.13
# Santa Cruz do Sul      -52.43     78.01        3.29
# Butembo                 29.28     63.25        3.15
# Hangu                  117.79     32.00        2.24
# Porbandar               69.61     57.20        4.16
# Bosobolo                19.90     68.67        1.95
# Labuhan                112.21     84.72        6.15
# Bakel                  -12.46     68.52       11.63
# Reserva                -50.85     62.13        1.90
# Mayumba                 10.66     82.35        8.30
# Qashyr                  76.10     23.16       16.13
# Risod                   76.78     68.92       10.80
# Jian                   114.98     45.55        2.10
# San Luis               -66.34     83.64        5.97
# Awjilah                 21.29     54.14        7.47
# Lucea                  -78.17     80.60       19.46
# Almeirim               -52.58     75.58        4.14
# Abbeyfeale              -9.30     41.00       20.80
# San Quintin           -115.95     56.17       10.85
# Broome                 -75.83     43.00        9.17
# Loa Janan              117.09     91.06        2.80
# Valentin Gomez Farias -106.58     59.00        1.99
# Bartica                -58.62     75.20        2.24
# Joaima                 -41.03     66.36        2.10
# Isiro                   27.62     63.52        1.86
# Quimper                 -4.10     57.20       21.92
# Manta                  -80.73     78.80        5.82
#
# [550 rows x 8 columns]

# %%
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# #### Latitude vs. Temperature Plot
plt.scatter(city_weather_df["Lat"], city_weather_df["Max Temp"], marker="o", edgecolor='black')
plt.title("City Latitude vs Max Temperature (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig('Lat_Temp_Plot.png')
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], marker="o", edgecolor='black')
plt.title("City Latitude vs Humidity (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True)
plt.savefig('Lat_Humidity_Plot.png')# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], marker="o", edgecolor='black')
plt.title("City Latitude vs Cloudiness (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.savefig('Lat_Cloudiness_Plot.png')
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], marker="o", edgecolor='black')
plt.title("City Latitude vs Wind Speed (08/24/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(True)
plt.savefig('Lat_Wind_Plot.png')
